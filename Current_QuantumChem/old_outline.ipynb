# %% [markdown]
# <font size=3 color=b64c35>Prev module:</font><font size=4 color=b64c35></font> &nbsp;&nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp;&nbsp; &nbsp;&nbsp;
# <font size=3 color=b64c35>Next module: </font> <font size=4 color=b64c35>[1. Electronic Structure](./1_Electronic_structure.ipynb)</font>

# %% [markdown]
# <h1 style="color:MediumSeaGreen;">Introduction to quantum simulation</h1>
#
# > "Nature isn't classical, dammit, and if you want to make a simulation of nature, you'd better make it quantum mechanical, and by golly it's a wonderful problem, because it doesn't look so easy." - Richard Feynman

# %% [markdown]
# <h1 style="color:MediumSeaGreen;">History</h1>

# %% [markdown]
# <h1 style="color:MediumSeaGreen;">Analog quantum simulation</h1>

# %% [markdown]
# <h1 style="color:MediumSeaGreen;">Digital quantum simulation</h1>

# %% [markdown]
# <h1 style="color:MediumSeaGreen;">Schrodinger's Equation</h1>
#
#
#
# <h1 style="color:MediumSeaGreen;">Born-Oppenheimer approximation</h1>
#
# <h2 style="color:MediumSeaGreen;">Electronic Hamiltonian</h2>
#
# <h2 style="color:MediumSeaGreen;">Nuclear Hamiltonian</h2>
#
# <h2 style="color:MediumSeaGreen;">Why is this problem important?</h2>
#
#
# <h2 style="color:MediumSeaGreen;">Orbitals/modes</h2>
# <h2 style="color:MediumSeaGreen;">Spatial and spin wave functions</h2>
#
# <h1 style="color:MediumSeaGreen;">Hartree product wavefunction</h1>
#
# <h2 style="color:MediumSeaGreen;">Anti-symmetry</h2>
#
# <h2 style="color:MediumSeaGreen;">Slater determinant</h2>
#
#
#
# <h2 style="color:MediumSeaGreen;">Basis-sets</h2>
#
# <h2 style="color:MediumSeaGreen;">N-particle wavefunction basis sets</h2>

# %% [markdown]
# <h1 style="color:MediumSeaGreen;"> Second quantization</h1>
# - Creation and annihilation operators
# - Vacuum state
# - Preparing N-body states
# - Hamiltonian in second quantization formalism

# %% [markdown]
# <h1 style="color:MediumSeaGreen;"> Classical methods for quantum simulation</h1>
# - Hartree-Fock method
# - Restricted Hartree-Fock
# - Unrestricted Hartree-Fock
# - Coupled-Cluster
# - Brief mention of Density Functional Theory (DFT)
# - Using pyscf
# - using Psi4

# %% [markdown]
# <h1 style="color:MediumSeaGreen;"> Fermionic Encodings</h1>
# - Discussion of fermionic algebra and qubit operator algebra
# - Jordan-Wigner
# - Parity
# - Fenwick
# - BKSF
# - Verstraete-Cirac
# - Using qiskit for the mappings
# - Using Openfermion for the mappings
# - exponential of pauli gates
# - PEA, QFT (reiterated)

# %% [markdown]
# <h1 style="color:MediumSeaGreen;"> Calculating ground state energy using phase estimation algorithm</h1>
# - Review of phase estimation algorithm
# - Trotterization
# - Approximate state preparation
# - important circuit components for creating the complete circuit.
# - exponential of pauli gates
# - Using qiskit and openfermion for getting the circuit

# %% [markdown]
# <h1 style="color:MediumSeaGreen;"> Ground state energy using variational quantum eigensolver (VQE)</h1>
# - Variational principle
# - Rayleigh-Ritz method
# - Description of hybrid strategy.
# - Ansatz preparation and measurement on a quantum computer.
# - Classical optimization.
